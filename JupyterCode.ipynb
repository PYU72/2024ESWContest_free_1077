# %% [markdown]
# # 임베디드 시스템 경진대회 코드

# %% [markdown]
# ## Servo X

# %%
# !pip install pyserial
# !pip install cvzone
# !pip install opencv-python
# !pip install mediapipe --user
# Out:
# Requirement already satisfied: pyserial in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (3.5)
# Requirement already satisfied: cvzone in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (1.6.1)
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from cvzone) (4.10.0.84)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from cvzone) (2.0.1)
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)

# %%
import cv2
import numpy as np
import time
import HandTrackingModule as htm
import math
import serial

ser = serial.Serial('COM8', 9600)

def send_right(right,state):
    ser.write(f"R{right},{state}\n".encode())
    print(f"Sent right: {right}, state: {state}")

def send_left(left, state):
    ser.write(f"L{left}, {state}\n".encode())
    print(f"Sent left: {left}, state: {state}")
    
def check_hand_state(fingers):
    # 엄지만 올라가 있고 나머지는 접혀있는 상태
    if fingers[0] == 1 and sum(fingers[1:]) == 0:
        return "Back"
    # 주먹을 쥔 상태 (모든 손가락이 접혀있음)
    elif sum(fingers) == 0:
        return "Fist"
    # 소지만 올라가 있고 나머지는 접혀있는 상태
    elif fingers[0] == 0 and fingers[1] == 0 and fingers[2] == 0 and fingers[3] == 0 and fingers[4] == 1:
        return "Front"
    else:
        return "Other"

def display_hand_state(img, left_state, right_state, left_hand, right_hand):
    # 왼손 상태 표시
    if left_state == "Back":
        cv2.putText(img, "LeftBack", (10, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    else:
        cv2.putText(img, "LeftFront", (10, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    
    # 오른손 상태 표시
    if right_state == "Back":
        cv2.putText(img, "RightBack", (wCam - 150, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    else:
        cv2.putText(img, "RightFront", (wCam - 150, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # 주먹 상태에 따른 텍스트 표시
    if len(left_hand) != 0 and check_hand_state(detector.fingersUpDown(left_hand, "Left")) == "Fist":
        cv2.putText(img, "Left Fist", (10, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    
    if len(right_hand) != 0 and check_hand_state(detector.fingersUpDown(right_hand, "Right")) == "Fist":
        cv2.putText(img, "Right Fist", (wCam - 150, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

left_state = "Front"
right_state = "Front"

wCam, hCam = 640, 480

cap = cv2.VideoCapture(1)
cap.set(3, wCam)
cap.set(4, hCam)
pTime = 0

detector = htm.handDetector(detectionCon=0.7)

while True:
    success, img = cap.read()
    img = detector.findHands(img)
    left_hand, right_hand = detector.findPosition(img, draw=False)

    # 왼손 처리
    if left_hand:
        # 엄지와 검지 랜드마크 (예: 4번과 8번)
        x1, y1 = left_hand[4][1], left_hand[4][2]
        x2, y2 = left_hand[8][1], left_hand[8][2]
        cx, cy = (x1+x2)//2, (y1+y2)//2
        
        cv2.circle(img, (x1, y1), 5, (255, 0, 0), cv2.FILLED)  # 파란색
        cv2.circle(img, (x2, y2), 5, (255, 0, 0), cv2.FILLED)  # 파란색
        cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 2)  # 파란색 선
        
        cv2.circle(img, (cx,cy), 5, (255,0,255), cv2.FILLED)
        
        left_length = int(math.hypot(x2-x1, y2-y1))
        
        if left_length<=15:
            cv2.circle(img, (cx,cy), 8, (0,255,0), cv2.FILLED)
            send_left(0, "F")
            time.sleep(0.1)
        
        # 주먹여부처리
        fingers_left = detector.fingersUpDown(left_hand, "Left")
        current_left_state = check_hand_state(fingers_left)
        
        # 상태 유지 로직
        if current_left_state == "Back":
            left_state = "Back"
        elif current_left_state == "Front":
            left_state = "Front"
        elif left_state == "Back" and current_left_state != "Front":
            # Back 상태를 유지
            pass
        else:
            left_state = current_left_state
        
        #아두이노 값 전송
        if left_state == "Back":
            send_left(left_length, "B")
            time.sleep(0.1)
        else:
            send_left(left_length, "F")
            time.sleep(0.1)
        

    # 오른손 처리
    if right_hand:
        # 엄지와 검지 랜드마크 (예: 4번과 8번)
        x1, y1 = right_hand[4][1], right_hand[4][2]
        x2, y2 = right_hand[8][1], right_hand[8][2]
        cx, cy = (x1+x2)//2, (y1+y2)//2
        
        cv2.circle(img, (x1, y1), 5, (0, 0, 255), cv2.FILLED)  # 빨간색
        cv2.circle(img, (x2, y2), 5, (0, 0, 255), cv2.FILLED)  # 빨간색
        cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2)  # 빨간색 선
        
        cv2.circle(img, (cx,cy), 5, (255,0,255), cv2.FILLED)
        
        right_length = int(math.hypot(x2-x1, y2-y1))
        
        if right_length<=15:
            cv2.circle(img, (cx,cy), 8, (0,255,0), cv2.FILLED)
            send_right(0, "F")
            time.sleep(0.1)
        
         #주먹여부처리
        fingers_right = detector.fingersUpDown(right_hand, "Right")
        current_right_state = check_hand_state(fingers_right)
        
        # 상태 유지 로직
        if current_right_state == "Back":
            right_state = "Back"
        elif current_right_state == "Front":
            right_state = "Front"
        elif right_state == "Back" and current_right_state != "Front":
            # Back 상태를 유지
            pass
        else:
            right_state = current_right_state
        
        if right_state == "Back":
            send_right(right_length, "B")
            time.sleep(0.1)
        else:
            send_right(right_length, "F")
            time.sleep(0.1)

    # 여기에 display_hand_state 함수 호출
    display_hand_state(img, left_state, right_state, left_hand, right_hand)
    
    # fps 확인
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    
    cv2.putText(img, f'FPS: {int(fps)}', (40, 80), cv2.FONT_HERSHEY_COMPLEX,
                1, (255, 0, 0), 3)
    
    cv2.imshow("Img", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):  # 'q' 키를 누르면 종료
        break
        
ser.close()
cap.release()
cv2.destroyAllWindows()
# Out:
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 81, state: F
# Sent left: 75, state: F
# Sent left: 51, state: B
# Sent left: 74, state: B
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 38, state: B
# Sent left: 81, state: B
# Sent left: 36, state: B
# Sent right: 79, state: F
# Sent left: 93, state: B
# Sent right: 120, state: F
# Sent right: 107, state: F
# Sent left: 123, state: B
# Sent right: 161, state: F
# Sent right: 34, state: F
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 48, state: F
# Sent left: 16, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 12, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 7, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 4, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 7, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 5, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 4, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 4, state: F
# Sent left: 0, state: F
# Sent left: 4, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 2, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 4, state: B
# Sent right: 0, state: F
# Sent right: 7, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 18, state: F
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent left: 22, state: B
# Sent right: 25, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 12, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 96, state: B
# Sent right: 93, state: F
# Sent left: 97, state: B
# Sent right: 89, state: F
# Sent left: 98, state: B
# Sent right: 88, state: F
# Sent left: 97, state: B
# Sent right: 90, state: F
# Sent left: 102, state: B
# Sent right: 92, state: F
# Sent left: 99, state: B
# Sent right: 92, state: F
# Sent left: 103, state: B
# Sent right: 94, state: F
# Sent left: 102, state: B
# Sent right: 95, state: F
# Sent left: 102, state: B
# Sent right: 95, state: F
# Sent left: 105, state: B
# Sent right: 93, state: F
# Sent left: 106, state: B
# Sent right: 94, state: F
# Sent left: 107, state: B
# Sent right: 96, state: F
# Sent left: 109, state: B
# Sent right: 95, state: F
# Sent left: 107, state: B
# Sent right: 97, state: F
# Sent left: 106, state: B
# Sent right: 95, state: F
# Sent left: 113, state: B
# Sent right: 95, state: F
# Sent left: 114, state: B
# Sent right: 99, state: F
# Sent left: 114, state: B
# Sent right: 101, state: F
# Sent left: 122, state: B
# Sent right: 100, state: F
# Sent left: 137, state: B
# Sent right: 107, state: F
# Sent left: 126, state: B
# Sent right: 105, state: F
# Sent left: 18, state: B
# Sent right: 25, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 12, state: F
# Sent left: 125, state: B
# Sent right: 110, state: F
# Sent left: 123, state: B
# Sent right: 109, state: F
# Sent left: 127, state: B
# Sent right: 118, state: F
# Sent left: 119, state: B
# Sent right: 106, state: F
# Sent left: 111, state: B
# Sent right: 102, state: F
# Sent left: 119, state: B
# Sent right: 100, state: F
# Sent left: 119, state: B
# Sent right: 98, state: F
# Sent left: 72, state: B
# Sent right: 56, state: F
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 118, state: B
# Sent right: 101, state: F
# Sent left: 119, state: B
# Sent right: 107, state: F
# Sent left: 127, state: B
# Sent right: 112, state: F
# Sent left: 103, state: B
# Sent right: 105, state: F
# Sent left: 125, state: B
# Sent right: 106, state: F
# Sent left: 123, state: B
# Sent right: 113, state: F
# Sent left: 101, state: B
# Sent right: 98, state: F
# Sent left: 118, state: B
# Sent right: 104, state: F
# Sent left: 58, state: B
# Sent right: 61, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 113, state: B
# Sent right: 102, state: F
# Sent left: 124, state: B
# Sent right: 120, state: F
# Sent left: 117, state: B
# Sent right: 88, state: F
# Sent left: 117, state: B
# Sent right: 96, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 93, state: B
# Sent right: 90, state: F
# Sent left: 116, state: B
# Sent right: 82, state: F
# Sent left: 107, state: B
# Sent right: 99, state: F
# Sent left: 110, state: B
# Sent right: 102, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 94, state: F
# Sent left: 49, state: B
# Sent right: 107, state: F
# Sent left: 121, state: B
# Sent right: 22, state: F
# Sent left: 105, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 134, state: B
# Sent right: 106, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 108, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 99, state: F
# Sent left: 43, state: B
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 122, state: B
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 113, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 114, state: F
# Sent left: 113, state: B
# Sent right: 101, state: F
# Sent left: 111, state: B
# Sent right: 87, state: F
# Sent left: 111, state: B
# Sent right: 95, state: F
# Sent left: 114, state: B
# Sent right: 98, state: F
# Sent left: 126, state: B
# Sent right: 105, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 20, state: B
# Sent right: 43, state: F
# Sent left: 117, state: B
# Sent right: 110, state: F
# Sent left: 127, state: B
# Sent right: 117, state: F
# Sent left: 128, state: B
# Sent right: 120, state: F
# Sent left: 136, state: B
# Sent right: 120, state: F
# Sent left: 143, state: B
# Sent right: 123, state: F
# Sent left: 153, state: B
# Sent right: 136, state: F
# Sent left: 171, state: B
# Sent right: 149, state: F
# Sent left: 181, state: B
# Sent right: 159, state: F
# Sent left: 185, state: B
# Sent right: 163, state: F
# Sent left: 180, state: B
# Sent right: 155, state: F
# Sent left: 181, state: B
# Sent right: 153, state: F
# Sent left: 180, state: B
# Sent right: 153, state: F
# Sent left: 184, state: B
# Sent right: 153, state: F
# Sent left: 186, state: B
# Sent right: 149, state: F
# Sent left: 186, state: B
# Sent right: 150, state: F
# Sent left: 181, state: B
# Sent right: 150, state: F
# Sent left: 176, state: B
# Sent right: 147, state: F
# Sent left: 176, state: B
# Sent right: 147, state: F
# Sent left: 177, state: B
# Sent right: 152, state: F
# Sent left: 180, state: B
# Sent right: 150, state: F
# Sent left: 180, state: B
# Sent right: 151, state: F
# Sent left: 181, state: B
# Sent right: 157, state: F
# Sent left: 178, state: B
# Sent right: 155, state: F
# Sent left: 176, state: B
# Sent right: 157, state: F
# Sent left: 183, state: B
# Sent right: 164, state: F
# Sent left: 188, state: B
# Sent right: 172, state: F
# Sent left: 188, state: B
# Sent right: 172, state: F
# Sent left: 185, state: B
# Sent right: 169, state: F
# Sent left: 183, state: B
# Sent right: 169, state: F
# Sent left: 189, state: B
# Sent right: 164, state: F
# Sent left: 190, state: B
# Sent right: 164, state: F
# Sent left: 191, state: B
# Sent right: 166, state: F
# Sent left: 193, state: B
# Sent right: 167, state: F
# Sent left: 191, state: B
# Sent right: 166, state: F
# Sent left: 192, state: B
# Sent right: 166, state: F
# Sent left: 194, state: B
# Sent right: 167, state: F
# Sent left: 194, state: B
# Sent right: 163, state: F
# Sent left: 187, state: B
# Sent right: 144, state: F
# Sent left: 186, state: B
# Sent right: 155, state: F
# Sent left: 187, state: B
# Sent right: 165, state: F
# Sent left: 196, state: B
# Sent right: 174, state: F
# Sent left: 202, state: B
# Sent right: 162, state: F
# Sent left: 191, state: B
# Sent right: 163, state: F
# Sent left: 178, state: B
# Sent right: 167, state: F
# Sent left: 177, state: B
# Sent right: 164, state: F
# Sent left: 183, state: B
# Sent right: 165, state: F
# Sent left: 185, state: B
# Sent right: 170, state: F
# Sent left: 192, state: B
# Sent right: 174, state: F
# Sent left: 193, state: B
# Sent right: 167, state: F
# Sent left: 184, state: B
# Sent right: 152, state: F
# Sent left: 204, state: B
# Sent right: 152, state: F
# Sent left: 187, state: B
# Sent right: 163, state: F
# Sent left: 186, state: B
# Sent right: 163, state: F
# Sent left: 184, state: B
# Sent right: 157, state: F
# Sent left: 176, state: B
# Sent right: 153, state: F
# Sent left: 176, state: B
# Sent right: 152, state: F
# Sent left: 174, state: B
# Sent right: 154, state: F
# Sent left: 175, state: B
# Sent right: 142, state: F
# Sent left: 171, state: B
# Sent right: 151, state: F
# Sent left: 171, state: B
# Sent right: 150, state: F
# Sent left: 173, state: B
# Sent right: 145, state: F
# Sent left: 178, state: B
# Sent right: 153, state: F
# Sent left: 196, state: B
# Sent right: 165, state: F
# Sent left: 189, state: B
# Sent right: 168, state: F
# Sent left: 190, state: B
# Sent right: 163, state: F
# Sent left: 193, state: B
# Sent right: 168, state: F
# Sent left: 197, state: B
# Sent right: 173, state: F
# Sent left: 189, state: B
# Sent right: 167, state: F
# Sent left: 187, state: B
# Sent right: 168, state: F
# Sent left: 185, state: B
# Sent right: 165, state: F
# Sent left: 184, state: B
# Sent right: 165, state: F
# Sent left: 182, state: B
# Sent right: 165, state: F
# Sent left: 182, state: B
# Sent right: 165, state: F
# Sent left: 184, state: B
# Sent right: 163, state: F
# Sent left: 182, state: B
# Sent right: 164, state: F
# Sent left: 182, state: B
# Sent right: 163, state: F
# Sent left: 180, state: B
# Sent right: 162, state: F
# Sent left: 183, state: B
# Sent right: 163, state: F
# Sent left: 172, state: B
# Sent right: 151, state: F
# Sent left: 118, state: B
# Sent right: 127, state: F
# Sent left: 158, state: B
# Sent right: 155, state: F
# Sent left: 162, state: B
# Sent right: 135, state: F
# Sent left: 170, state: B
# Sent right: 140, state: F
# Sent left: 153, state: B
# Sent right: 135, state: F
# Sent left: 152, state: B
# Sent right: 177, state: F
# Sent left: 171, state: B
# Sent right: 187, state: F
# Sent left: 172, state: B
# Sent right: 164, state: F
# Sent left: 184, state: B
# Sent right: 176, state: F
# Sent left: 184, state: B
# Sent right: 137, state: F
# Sent left: 150, state: B
# Sent right: 139, state: F
# Sent left: 163, state: B
# Sent right: 142, state: F
# Sent left: 190, state: B
# Sent right: 139, state: F
# Sent left: 138, state: B
# Sent right: 115, state: F
# Sent left: 58, state: B
# Sent right: 73, state: F
# Sent left: 152, state: B
# Sent right: 155, state: F
# Sent left: 87, state: B
# Sent right: 161, state: F
# Sent left: 16, state: B
# Sent right: 144, state: F
# Sent left: 18, state: B
# Sent right: 111, state: F
# Sent left: 21, state: B
# Sent right: 75, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 34, state: F
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 12, state: F
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 191, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 192, state: B
# Sent right: 16, state: F
# Sent left: 187, state: B
# Sent right: 16, state: F
# Sent left: 16, state: B
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 17, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 16, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 16, state: B
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 38, state: F
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 148, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 78, state: F
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 31, state: F
# Sent left: 17, state: B
# Sent right: 26, state: F
# Sent left: 20, state: B
# Sent right: 23, state: F
# Sent left: 17, state: B
# Sent right: 21, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 16, state: F
# Sent left: 20, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 21, state: B
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 3, state: F
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 12, state: F
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 7, state: F
# Sent left: 0, state: F
# Sent left: 3, state: B
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 25, state: B
# Sent right: 0, state: F
# Sent right: 7, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 34, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 49, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 19, state: B
# Sent left: 16, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 37, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 42, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 30, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 25, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 29, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 29, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 25, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 36, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 35, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 19, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 25, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent right: 48, state: B
# Sent left: 0, state: F
# Sent left: 3, state: F
# Sent right: 28, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 15, state: F
# Sent right: 36, state: B
# Sent left: 73, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 0, state: F
# Sent right: 8, state: B
# Sent left: 45, state: B
# Sent right: 16, state: B
# Sent left: 24, state: B
# Sent left: 30, state: B
# Sent right: 0, state: F
# Sent right: 5, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 2, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 7, state: B
# Sent left: 39, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 16, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 182, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 196, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 173, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 17, state: B
# Sent right: 0, state: F
# Sent right: 8, state: B
# Sent left: 18, state: B
# Sent right: 0, state: F
# Sent right: 5, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 43, state: B
# Sent right: 0, state: F
# Sent right: 7, state: B
# Sent left: 86, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 67, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 67, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 18, state: B
# Sent right: 66, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 171, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 209, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 218, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 218, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 214, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 215, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 209, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 32, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 152, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 199, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 182, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 178, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 73, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 18, state: B
# Sent right: 27, state: B
# Sent left: 152, state: B
# Sent right: 127, state: B
# Sent left: 177, state: B
# Sent right: 144, state: B
# Sent left: 148, state: B
# Sent right: 115, state: B
# Sent left: 28, state: B
# Sent right: 20, state: B
# Sent left: 59, state: B
# Sent right: 0, state: F
# Sent right: 2, state: B
# Sent left: 28, state: B
# Sent right: 0, state: F
# Sent right: 6, state: B
# Sent left: 21, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent left: 38, state: B
# Sent right: 52, state: B
# Sent left: 25, state: B
# Sent right: 46, state: B
# Sent left: 18, state: B
# Sent right: 59, state: B
# Sent left: 73, state: B
# Sent right: 57, state: B
# Sent right: 39, state: B
# Sent right: 76, state: B
# Sent right: 38, state: B
# Sent left: 56, state: B
# Sent right: 73, state: B
# Sent left: 96, state: B
# Sent right: 53, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 8, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 36, state: B
# Sent right: 0, state: F
# Sent right: 5, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 16, state: B
# Sent left: 19, state: B
# Sent right: 23, state: B
# Sent left: 17, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 17, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 21, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 19, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 17, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 14, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 111, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 154, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 145, state: B
# Sent left: 155, state: B
# Sent right: 148, state: B
# Sent left: 170, state: B
# Sent right: 146, state: B
# Sent left: 162, state: B
# Sent right: 146, state: B
# Sent left: 164, state: B
# Sent right: 145, state: B
# Sent left: 164, state: B
# Sent right: 142, state: B
# Sent left: 153, state: B
# Sent right: 148, state: B
# Sent left: 150, state: B
# Sent right: 135, state: B
# Sent left: 148, state: B
# Sent right: 132, state: B
# Sent left: 144, state: B
# Sent right: 134, state: B
# Sent left: 152, state: B
# Sent right: 143, state: B
# Sent left: 152, state: B
# Sent right: 144, state: B
# Sent left: 142, state: B
# Sent right: 141, state: B
# Sent left: 142, state: B
# Sent right: 139, state: B
# Sent left: 147, state: B
# Sent right: 142, state: B
# Sent left: 153, state: B
# Sent right: 148, state: B
# Sent left: 152, state: B
# Sent right: 156, state: B
# Sent left: 136, state: B
# Sent right: 160, state: B
# Sent left: 162, state: B
# Sent right: 162, state: B
# Sent left: 70, state: B
# Sent right: 167, state: B
# Sent left: 62, state: B
# Sent right: 165, state: B
# Sent left: 66, state: B
# Sent right: 162, state: B
# Sent left: 122, state: B
# Sent right: 111, state: B
# Sent left: 168, state: B
# Sent right: 60, state: B
# Sent left: 172, state: B
# Sent right: 57, state: B
# Sent left: 173, state: B
# Sent right: 47, state: B
# Sent left: 174, state: B
# Sent right: 48, state: B
# Sent left: 165, state: B
# Sent right: 47, state: B
# Sent left: 168, state: B
# Sent right: 49, state: B
# Sent left: 147, state: B
# Sent right: 51, state: B
# Sent left: 119, state: B
# Sent right: 59, state: B
# Sent left: 126, state: B
# Sent right: 64, state: B
# Sent left: 117, state: B
# Sent right: 69, state: B
# Sent left: 121, state: B
# Sent right: 99, state: B
# Sent left: 73, state: B
# Sent right: 91, state: B
# Sent left: 48, state: B
# Sent right: 65, state: B
# Sent left: 53, state: B
# Sent right: 52, state: B
# Sent left: 49, state: B
# Sent right: 48, state: B
# Sent left: 38, state: B
# Sent right: 43, state: B
# Sent left: 45, state: B
# Sent right: 45, state: B
# Sent left: 73, state: B
# Sent right: 103, state: B
# Sent left: 190, state: B
# Sent right: 194, state: B
# Sent left: 201, state: B
# Sent right: 197, state: B
# Sent left: 200, state: B
# Sent right: 201, state: B
# Sent left: 201, state: B
# Sent right: 195, state: B
# Sent left: 198, state: B
# Sent right: 192, state: B
# Sent left: 198, state: B
# Sent right: 191, state: B
# Sent left: 196, state: B
# Sent right: 181, state: B
# Sent left: 192, state: B
# Sent right: 175, state: B
# Sent left: 192, state: B
# Sent right: 181, state: B
# Sent left: 182, state: B
# Sent right: 181, state: B
# Sent left: 166, state: B
# Sent right: 184, state: B
# Sent left: 152, state: B
# Sent right: 185, state: B
# Sent left: 171, state: B
# Sent right: 187, state: B
# Sent left: 211, state: B
# Sent right: 101, state: B
# Sent left: 213, state: B
# Sent right: 35, state: B
# Sent left: 218, state: B
# Sent right: 31, state: B
# Sent left: 222, state: B
# Sent right: 16, state: B
# Sent left: 217, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 218, state: B
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 220, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 223, state: B
# Sent right: 0, state: F
# Sent right: 7, state: B
# Sent left: 225, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 226, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 225, state: B
# Sent right: 0, state: F
# Sent right: 6, state: B
# Sent left: 228, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 228, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 229, state: B
# Sent right: 0, state: F
# Sent right: 5, state: B
# Sent left: 226, state: B
# Sent right: 0, state: F
# Sent right: 5, state: B
# Sent left: 225, state: B
# Sent right: 0, state: F
# Sent right: 9, state: B
# Sent left: 225, state: B
# Sent right: 0, state: F
# Sent right: 7, state: B
# Sent left: 220, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 34, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 210, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 197, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 212, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 217, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 219, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 223, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 221, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 219, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 220, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 219, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 219, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 217, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 216, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 212, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 217, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 217, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 216, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent right: 216, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 205, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 97, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 27, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 31, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 63, state: B
# Sent left: 121, state: B
# Sent right: 110, state: B
# Sent left: 199, state: B
# Sent right: 203, state: B
# Sent left: 190, state: B
# Sent right: 160, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 0, state: F
# Sent right: 6, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 17, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 142, state: B
# Sent right: 120, state: B
# Sent left: 160, state: B
# Sent right: 169, state: B
# Sent left: 162, state: B
# Sent right: 141, state: B
# Sent left: 149, state: B
# Sent right: 147, state: B
# Sent left: 151, state: B
# Sent right: 137, state: B
# Sent left: 141, state: B
# Sent right: 139, state: B
# Sent left: 139, state: B
# Sent right: 128, state: B
# Sent left: 156, state: B
# Sent right: 129, state: B
# Sent left: 153, state: B
# Sent right: 135, state: B
# Sent left: 163, state: B
# Sent right: 136, state: B
# Sent left: 148, state: B
# Sent right: 146, state: B
# Sent left: 147, state: B
# Sent right: 148, state: B
# Sent left: 135, state: B
# Sent right: 144, state: B
# Sent left: 143, state: B
# Sent right: 138, state: B
# Sent left: 142, state: B
# Sent right: 162, state: B
# Sent left: 142, state: B
# Sent right: 159, state: B
# Sent left: 146, state: B
# Sent right: 174, state: B
# Sent left: 146, state: B
# Sent right: 166, state: B
# Sent left: 136, state: B
# Sent right: 161, state: B
# Sent left: 139, state: B
# Sent right: 156, state: B
# Sent left: 137, state: B
# Sent right: 147, state: B
# Sent left: 131, state: B
# Sent right: 143, state: B
# Sent left: 135, state: B
# Sent right: 144, state: B
# Sent left: 135, state: B
# Sent right: 137, state: B
# Sent left: 138, state: B
# Sent right: 125, state: B
# Sent left: 125, state: B
# Sent right: 119, state: B
# Sent left: 136, state: B
# Sent right: 121, state: B
# Sent left: 131, state: B
# Sent right: 128, state: B
# Sent left: 132, state: B
# Sent right: 132, state: B
# Sent left: 132, state: B
# Sent right: 130, state: B
# Sent left: 134, state: B
# Sent right: 132, state: B
# Sent left: 138, state: B
# Sent right: 133, state: B
# Sent left: 66, state: B
# Sent right: 130, state: B
# Sent left: 24, state: B
# Sent right: 127, state: B
# Sent left: 41, state: B
# Sent right: 126, state: B
# Sent left: 54, state: F
# Sent right: 121, state: B
# Sent left: 54, state: F
# Sent left: 52, state: F
# Sent left: 62, state: F
# Sent left: 51, state: F
# Sent left: 58, state: F
# Sent left: 57, state: F
# Sent left: 53, state: F
# Sent left: 52, state: F
# Sent left: 49, state: F
# Sent left: 51, state: F
# Sent left: 49, state: F
# Sent left: 49, state: F
# Sent left: 41, state: F
# Sent left: 0, state: F
# Sent left: 8, state: F
# Sent left: 33, state: F
# Sent left: 48, state: F
# Sent left: 32, state: F
# Sent right: 30, state: B
# Sent right: 17, state: B
# Sent right: 22, state: B
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent right: 46, state: B
# Sent right: 18, state: B
# Sent right: 38, state: B
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent right: 32, state: B
# Sent right: 38, state: B
# Sent right: 25, state: B
# Sent right: 30, state: B
# Sent right: 35, state: B
# Sent right: 32, state: B
# Sent right: 50, state: B
# Sent right: 65, state: B
# Sent right: 75, state: B
# Sent right: 73, state: B
# Sent right: 78, state: B
# Sent right: 85, state: B
# Sent right: 85, state: B
# Sent right: 72, state: B
# Sent right: 60, state: B
# Sent right: 55, state: B
# Sent right: 57, state: B
# Sent right: 57, state: B
# Sent right: 57, state: B
# Sent right: 57, state: B
# Sent right: 57, state: B
# Sent right: 59, state: B
# Sent right: 57, state: B
# Sent right: 60, state: B
# Sent right: 58, state: B
# Sent right: 57, state: B
# Sent right: 59, state: B
# Sent right: 39, state: B
# Sent right: 45, state: B
# Sent right: 47, state: B
# Sent right: 40, state: B
# Sent right: 35, state: B
# Sent right: 50, state: B
# Sent right: 34, state: B
# Sent right: 54, state: B
# Sent right: 118, state: B
# Sent right: 127, state: B
# Sent right: 119, state: B
# Sent right: 114, state: B
# Sent right: 113, state: B
# Sent right: 106, state: B
# Sent left: 0, state: F
# Sent left: 13, state: F
# Sent right: 108, state: B
# Sent left: 16, state: F
# Sent right: 109, state: B
# Sent left: 0, state: F
# Sent left: 13, state: F
# Sent right: 111, state: B
# Sent left: 0, state: F
# Sent left: 8, state: F
# Sent right: 112, state: B
# Sent left: 16, state: B
# Sent right: 107, state: B
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 107, state: B
# Sent left: 32, state: B
# Sent right: 108, state: B
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 104, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 103, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 103, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 108, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent right: 100, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 88, state: B
# Sent left: 17, state: B
# Sent right: 57, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent right: 86, state: B
# Sent left: 96, state: B
# Sent left: 111, state: B
# Sent left: 114, state: B
# Sent left: 120, state: B
# Sent right: 95, state: B
# Sent left: 118, state: B
# Sent right: 80, state: B
# Sent left: 120, state: B
# Sent right: 101, state: B
# Sent left: 120, state: B
# Sent right: 101, state: B
# Sent left: 123, state: B
# Sent right: 101, state: B
# Sent left: 158, state: B
# Sent right: 102, state: B
# Sent left: 93, state: B
# Sent right: 107, state: B
# Sent left: 0, state: F
# Sent left: 12, state: B
# Sent right: 107, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 104, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 102, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 100, state: B
# Sent left: 170, state: B
# Sent right: 89, state: B
# Sent left: 165, state: B
# Sent right: 88, state: B
# Sent left: 171, state: B
# Sent right: 77, state: B
# Sent right: 69, state: B
# Sent right: 68, state: B
# Sent right: 72, state: B
# Sent left: 48, state: B
# Sent left: 62, state: B
# Sent left: 41, state: B
# Sent right: 78, state: B
# Sent left: 44, state: B
# Sent left: 24, state: B
# Sent left: 78, state: B
# Sent right: 56, state: B
# Sent left: 92, state: B
# Sent right: 71, state: B
# Sent left: 90, state: B
# Sent right: 71, state: B
# Sent left: 84, state: B
# Sent right: 71, state: B
# Sent left: 87, state: B
# Sent right: 70, state: B
# Sent left: 37, state: B
# Sent right: 70, state: B
# Sent left: 91, state: B
# Sent right: 67, state: B
# Sent left: 96, state: B
# Sent right: 69, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent right: 69, state: B
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent right: 71, state: B
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 6, state: B
# Sent left: 0, state: F
# Sent left: 7, state: B
# Sent left: 0, state: F
# Sent left: 5, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent left: 0, state: F
# Sent left: 11, state: B
# Sent left: 0, state: F
# Sent left: 8, state: B
# Sent left: 0, state: F
# Sent left: 9, state: B
# Sent right: 38, state: B
# Sent left: 16, state: F
# Sent left: 22, state: F
# Sent right: 0, state: F
# Sent right: 14, state: F
# Sent left: 22, state: F
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 20, state: F
# Sent right: 0, state: F
# Sent right: 9, state: F
# Sent left: 22, state: F
# Sent right: 31, state: F
# Sent left: 83, state: F
# Sent right: 80, state: F
# Sent left: 88, state: F
# Sent right: 85, state: F
# Sent left: 92, state: F
# Sent right: 87, state: F
# Sent left: 93, state: F
# Sent right: 91, state: F
# Sent left: 106, state: F
# Sent right: 100, state: F
# Sent left: 110, state: F
# Sent right: 99, state: F
# Sent left: 112, state: F
# Sent right: 101, state: F
# Sent left: 110, state: F
# Sent right: 99, state: F
# Sent left: 114, state: F
# Sent right: 101, state: F
# Sent left: 134, state: F
# Sent right: 107, state: F
# Sent left: 154, state: F
# Sent right: 123, state: F
# Sent left: 164, state: F
# Sent right: 136, state: F
# Sent left: 170, state: F
# Sent right: 145, state: F
# Sent left: 173, state: F
# Sent right: 149, state: F
# Sent left: 175, state: F
# Sent right: 158, state: F
# Sent left: 181, state: F
# Sent right: 162, state: F
# Sent left: 178, state: F
# Sent right: 158, state: F
# Sent left: 180, state: F
# Sent right: 156, state: F
# Sent left: 175, state: F
# Sent right: 157, state: F
# Sent left: 175, state: F
# Sent right: 155, state: F
# Sent left: 170, state: F
# Sent right: 152, state: F
# Sent left: 173, state: F
# Sent right: 151, state: F
# Sent left: 174, state: F
# Sent right: 150, state: F
# Sent left: 181, state: F
# Sent right: 155, state: F
# Sent left: 183, state: F
# Sent right: 157, state: F
# Sent left: 179, state: F
# Sent right: 159, state: F
# Sent left: 186, state: F
# Sent right: 159, state: F
# Sent left: 178, state: F
# Sent right: 157, state: F
# Sent left: 178, state: F
# Sent right: 151, state: F
# Sent left: 178, state: F
# Sent right: 156, state: F
# Sent left: 177, state: F
# Sent right: 157, state: F
# Sent left: 189, state: F
# Sent right: 162, state: F
# Sent left: 179, state: F
# Sent right: 132, state: F
# Sent left: 181, state: F
# Sent right: 153, state: F
# Sent left: 157, state: F
# Sent right: 150, state: F
# Sent left: 71, state: F
# Sent right: 107, state: F
# Sent left: 182, state: F
# Sent right: 162, state: F
# Sent left: 189, state: F
# Sent right: 134, state: F
# Sent left: 196, state: F
# Sent right: 136, state: F
# Sent left: 0, state: F
# Sent left: 9, state: F
# Sent right: 62, state: F
# Sent left: 183, state: F
# Sent right: 172, state: F
# Sent left: 155, state: F
# Sent right: 154, state: F
# Sent left: 0, state: F
# Sent left: 6, state: F
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 191, state: F
# Sent right: 178, state: F
# Sent left: 147, state: F
# Sent right: 146, state: F
# Sent left: 174, state: F
# Sent right: 159, state: F
# Sent left: 173, state: F
# Sent right: 155, state: F
# Sent left: 178, state: F
# Sent right: 148, state: F
# Sent left: 156, state: F
# Sent right: 137, state: F
# Sent left: 165, state: F
# Sent right: 134, state: F
# Sent left: 164, state: F
# Sent right: 143, state: F
# Sent left: 170, state: F
# Sent right: 152, state: F
# Sent left: 176, state: F
# Sent right: 148, state: F
# Sent left: 183, state: F
# Sent right: 146, state: F
# Sent left: 191, state: F
# Sent right: 141, state: F
# Sent left: 192, state: F
# Sent right: 141, state: F
# Sent left: 183, state: F
# Sent right: 146, state: F
# Sent left: 183, state: F
# Sent right: 142, state: F
# Sent left: 197, state: F
# Sent right: 150, state: F
# Sent left: 183, state: F
# Sent right: 146, state: F
# Sent left: 192, state: F
# Sent right: 144, state: F
# Sent left: 177, state: F
# Sent right: 129, state: F
# Sent left: 87, state: F
# Sent right: 95, state: F
# Sent left: 83, state: F
# Sent right: 39, state: F
# Sent left: 172, state: F
# Sent right: 158, state: F
# Sent left: 16, state: F
# Sent right: 46, state: F
# Sent right: 31, state: F
# Sent right: 24, state: B
# Sent right: 30, state: B
# Sent right: 26, state: B
# Sent right: 31, state: B
# Sent right: 27, state: B
# Sent right: 73, state: B
# Sent left: 69, state: F
# Sent right: 99, state: B
# Sent left: 159, state: F
# Sent right: 141, state: B
# Sent left: 174, state: F
# Sent right: 129, state: B
# Sent left: 168, state: F
# Sent right: 157, state: B
# Sent left: 166, state: F
# Sent right: 150, state: B
# Sent left: 162, state: F
# Sent right: 153, state: B
# Sent left: 128, state: F
# Sent right: 117, state: B
# Sent left: 144, state: F
# Sent right: 126, state: B
# Sent left: 142, state: F
# Sent right: 125, state: B
# Sent left: 152, state: F
# Sent right: 140, state: B
# Sent left: 155, state: F
# Sent right: 124, state: B
# Sent left: 168, state: F
# Sent right: 167, state: B
# Sent left: 176, state: F
# Sent right: 114, state: B
# Sent left: 158, state: F
# Sent right: 125, state: B
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 16, state: B
# Sent left: 0, state: F
# Sent left: 11, state: F
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 11, state: F
# Sent right: 0, state: F
# Sent right: 15, state: B
# Sent left: 0, state: F
# Sent left: 4, state: F
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 6, state: F
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 19, state: F
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 12, state: F
# Sent right: 0, state: F
# Sent right: 14, state: B
# Sent left: 0, state: F
# Sent left: 8, state: F
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 12, state: F
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 9, state: F
# Sent right: 0, state: F
# Sent right: 13, state: B
# Sent left: 0, state: F
# Sent left: 8, state: F
# Sent right: 0, state: F
# Sent right: 12, state: B
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 0, state: F
# Sent right: 11, state: B
# Sent left: 0, state: F
# Sent left: 8, state: F
# Sent right: 0, state: F
# Sent right: 7, state: B
# Sent left: 0, state: F
# ...
# Sent left: 0, state: F
# Sent left: 9, state: F
# Sent right: 16, state: F
# Sent left: 170, state: F
# Sent right: 167, state: F
# Sent left: 174, state: F
# Sent right: 173, state: F
# Sent left: 178, state: F
# Sent right: 177, state: F
# Sent left: 175, state: F
# Sent right: 170, state: F
# Sent left: 175, state: F
# Sent right: 167, state: F
# Sent left: 173, state: F
# Sent right: 161, state: F
# Sent left: 172, state: F
# Sent right: 168, state: F
# Sent left: 173, state: F
# Sent right: 167, state: F
# Sent left: 182, state: F
# Sent right: 163, state: F
# Sent left: 186, state: F
# Sent right: 153, state: F
# Sent left: 121, state: F
# Sent right: 99, state: F
# Sent left: 92, state: F
# Sent right: 61, state: F
# Sent left: 60, state: F
# Sent right: 52, state: F
# Sent left: 49, state: F
# Sent right: 43, state: F
# Sent left: 54, state: F
# Sent right: 45, state: F
# Sent left: 57, state: F
# Sent right: 44, state: F
# Sent left: 54, state: F
# Sent right: 42, state: F
# Sent left: 64, state: F
# Sent right: 42, state: F
# Sent left: 82, state: F
# Sent right: 42, state: F
# Sent left: 32, state: F
# Sent right: 38, state: F
# Sent left: 0, state: F
# Sent left: 9, state: F
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 0, state: F
# Sent right: 10, state: F
# Sent left: 0, state: F
# Sent left: 12, state: F
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 0, state: F
# Sent left: 7, state: F
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 0, state: F
# Sent right: 15, state: F
# Sent left: 0, state: F
# Sent left: 12, state: F
# Sent right: 17, state: F
# Sent left: 0, state: F
# Sent left: 11, state: F
# Sent right: 19, state: F
# Sent left: 0, state: F
# Sent left: 11, state: F
# Sent right: 19, state: F
# Sent left: 18, state: F
# Sent right: 19, state: F
# Sent left: 109, state: F
# Sent right: 17, state: F
# Sent left: 142, state: F
# Sent right: 18, state: F
# Sent left: 133, state: F
# Sent right: 18, state: F
# Sent left: 130, state: F
# Sent right: 37, state: F
# Sent left: 134, state: F
# Sent right: 32, state: F
# Sent left: 138, state: F
# Sent right: 31, state: F
# Sent left: 138, state: F
# Sent right: 30, state: F
# Sent left: 140, state: F
# Sent right: 28, state: F
# Sent left: 144, state: F
# Sent right: 31, state: F
# Sent left: 145, state: F
# Sent right: 32, state: F
# Sent left: 144, state: F
# Sent right: 32, state: F
# Sent left: 144, state: F
# Sent right: 34, state: F
# Sent left: 138, state: F
# Sent right: 45, state: F
# Sent left: 75, state: F
# Sent right: 120, state: F
# Sent left: 61, state: F
# Sent right: 187, state: F
# Sent left: 42, state: F
# Sent right: 147, state: F
# Sent left: 44, state: F
# Sent right: 139, state: F
# Sent left: 40, state: F
# Sent right: 131, state: F
# Sent left: 40, state: F
# Sent right: 117, state: F
# Sent left: 35, state: F
# Sent right: 109, state: F
# Sent left: 39, state: F
# Sent right: 106, state: F
# Sent left: 38, state: F
# Sent right: 101, state: F
# Sent left: 41, state: F
# Sent right: 91, state: F
# Sent left: 38, state: F
# Sent right: 91, state: F
# Sent left: 38, state: F
# Sent right: 93, state: F
# Sent left: 41, state: F
# Sent right: 97, state: F
# Sent left: 41, state: F
# Sent right: 93, state: F
# Sent left: 40, state: F
# Sent right: 96, state: F
# Sent left: 41, state: F
# Sent right: 97, state: F
# Sent left: 42, state: F
# Sent right: 97, state: F
# Sent left: 45, state: F
# Sent right: 79, state: F
# Sent left: 41, state: F
# Sent right: 67, state: F
# Sent left: 39, state: F
# Sent right: 41, state: F
# Sent left: 0, state: F
# Sent left: 13, state: F
# Sent right: 16, state: F
# Sent left: 0, state: F
# Sent left: 13, state: F
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 0, state: F
# Sent left: 12, state: F
# Sent right: 0, state: F
# Sent right: 12, state: F
# Sent left: 16, state: F
# Sent right: 0, state: F
# Sent right: 8, state: F
# Sent left: 99, state: B
# Sent right: 99, state: B
# Sent left: 126, state: B
# Sent right: 122, state: B
# Sent left: 132, state: B
# Sent right: 128, state: B
# Sent left: 139, state: B
# Sent right: 143, state: B
# Sent left: 156, state: B
# Sent right: 140, state: B
# Sent left: 156, state: B
# Sent right: 132, state: F
# Sent left: 157, state: B
# Sent right: 134, state: F
# Sent left: 152, state: B
# Sent right: 133, state: F
# Sent left: 145, state: B
# Sent right: 150, state: F
# Sent left: 150, state: B
# Sent right: 141, state: F
# Sent left: 158, state: B
# Sent right: 143, state: F
# Sent left: 159, state: B
# Sent right: 131, state: F
# Sent left: 147, state: B
# Sent right: 129, state: F
# Sent left: 151, state: B
# Sent right: 136, state: F
# Sent left: 146, state: B
# Sent right: 130, state: F
# Sent left: 142, state: B
# Sent right: 124, state: F
# Sent left: 139, state: B
# Sent right: 123, state: F
# Sent left: 135, state: B
# Sent right: 119, state: F
# Sent left: 123, state: B
# Sent right: 103, state: F
# Sent left: 47, state: B
# Sent left: 53, state: F
# Sent left: 53, state: F
# Sent left: 48, state: F
# Sent right: 32, state: F
# Sent left: 85, state: F
# Sent right: 46, state: F
# Sent left: 82, state: F
# Sent right: 39, state: F
# Sent left: 72, state: F
# Sent right: 35, state: F
# Sent left: 76, state: F
# Sent right: 37, state: F
# Sent left: 79, state: F
# Sent right: 35, state: F
# Sent left: 83, state: F
# Sent right: 36, state: F
# Sent left: 88, state: F
# Sent right: 36, state: F
# Sent left: 76, state: F
# Sent right: 36, state: F
# Sent left: 79, state: F
# Sent right: 40, state: F
# Sent left: 75, state: F
# Sent right: 40, state: F
# Sent left: 73, state: F
# Sent right: 38, state: F
# Sent left: 71, state: F
# Sent right: 34, state: F
# Sent left: 66, state: F
# Sent right: 0, state: F
# Sent right: 6, state: F
# Sent left: 121, state: F
# Sent right: 95, state: F
# Sent left: 30, state: F
# Sent right: 39, state: F
# Sent left: 18, state: F
# Sent right: 85, state: F
# Sent left: 119, state: F
# Sent right: 186, state: F
# Sent left: 266, state: F
# Sent right: 202, state: F
# Sent left: 25, state: F
# Sent right: 169, state: F
# Sent left: 26, state: F
# Sent right: 73, state: F
# Sent left: 246, state: F
# Sent right: 216, state: F
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 68, state: F
# Sent left: 0, state: F
# Sent left: 13, state: F
# Sent right: 18, state: F
# Sent left: 34, state: F
# Sent right: 50, state: F
# Sent left: 250, state: F
# Sent right: 214, state: F
# Sent left: 0, state: F
# Sent left: 13, state: F
# Sent right: 56, state: F
# Sent left: 74, state: F
# Sent right: 102, state: F
# Sent left: 271, state: F
# Sent right: 235, state: F
# Sent left: 49, state: F
# Sent right: 206, state: F
# Sent left: 0, state: F
# Sent left: 10, state: F
# Sent right: 0, state: F
# Sent right: 11, state: F
# Sent left: 64, state: F
# Sent right: 23, state: F
# Sent left: 269, state: F
# Sent right: 224, state: F
# Sent left: 0, state: F
# Sent left: 8, state: F
# Sent right: 167, state: F
# Sent left: 16, state: F
# Sent right: 16, state: F
# Sent left: 17, state: B
# Sent left: 0, state: F
# Sent left: 10, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent left: 17, state: B
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent left: 17, state: B
# Sent left: 25, state: B
# Sent left: 17, state: B
# Sent left: 23, state: B
# Sent left: 27, state: B
# Sent left: 17, state: B
# Sent left: 33, state: B
# Sent left: 28, state: B
# Sent left: 19, state: B
# Sent left: 151, state: B
# Sent left: 130, state: B
# Sent right: 151, state: F
# Sent left: 171, state: B
# Sent right: 170, state: F
# Sent left: 188, state: B
# Sent right: 170, state: F
# Sent left: 176, state: B
# Sent right: 167, state: F
# Sent left: 196, state: B
# Sent right: 167, state: F
# Sent left: 220, state: B
# Sent right: 181, state: F
# Sent left: 198, state: B
# Sent right: 182, state: F
# Sent left: 195, state: B
# Sent right: 176, state: F
# Sent left: 200, state: B
# Sent right: 177, state: F
# Sent left: 209, state: B
# Sent right: 183, state: F
# Sent left: 206, state: B
# Sent right: 187, state: F
# Sent left: 165, state: B
# Sent right: 144, state: F
# Sent left: 167, state: B
# Sent right: 142, state: F
# Sent left: 136, state: B
# Sent right: 130, state: F
# Sent left: 133, state: B
# Sent right: 124, state: F
# Sent left: 149, state: B
# Sent right: 148, state: F
# Sent left: 130, state: B
# Sent right: 125, state: F
# Sent left: 81, state: B
# Sent right: 62, state: F
# Sent left: 45, state: B
# Sent right: 45, state: F
# Sent left: 35, state: B
# Sent right: 39, state: F
# Sent left: 31, state: B
# Sent right: 27, state: F
# Sent left: 34, state: B
# Sent right: 28, state: F
# Sent left: 34, state: B
# Sent right: 27, state: F
# Sent left: 36, state: B
# Sent right: 36, state: F
# Sent left: 46, state: B
# Sent right: 61, state: F
# Sent left: 75, state: B
# Sent right: 86, state: F
# Sent left: 97, state: B
# Sent right: 115, state: F
# Sent left: 129, state: B
# Sent right: 168, state: F
# Sent left: 163, state: B
# Sent right: 188, state: F
# Sent left: 192, state: B
# Sent right: 205, state: F
# Sent left: 224, state: B
# Sent right: 229, state: F
# Sent left: 226, state: B
# Sent right: 230, state: F
# Sent left: 224, state: B
# Sent right: 226, state: F
# Sent left: 221, state: B
# Sent right: 230, state: F
# Sent left: 218, state: B
# Sent right: 217, state: F
# Sent left: 197, state: B
# Sent right: 212, state: F
# Sent left: 219, state: B
# Sent right: 216, state: F
# Sent left: 222, state: B
# Sent right: 218, state: F
# Sent left: 219, state: B
# Sent right: 213, state: F
# Sent left: 160, state: B
# Sent right: 166, state: F
# Sent left: 134, state: B
# Sent right: 125, state: F
# Sent left: 114, state: B
# Sent right: 98, state: F
# Sent left: 88, state: B
# Sent right: 60, state: F
# Sent left: 72, state: B
# Sent right: 51, state: F
# Sent left: 58, state: B
# Sent right: 38, state: F
# Sent left: 40, state: B
# Sent right: 27, state: F
# Sent left: 35, state: B
# Sent right: 24, state: F
# Sent left: 27, state: B
# Sent right: 18, state: F
# Sent left: 0, state: F
# Sent left: 15, state: B
# Sent right: 0, state: F
# Sent right: 13, state: F
# Sent left: 68, state: B
# Sent right: 73, state: F
# Sent left: 105, state: B
# Sent right: 108, state: F
# Sent left: 140, state: B
# Sent right: 147, state: F
# Sent left: 179, state: B
# Sent right: 201, state: F
# Sent left: 209, state: B
# Sent right: 210, state: F
# Sent left: 226, state: B
# Sent right: 216, state: F
# Sent left: 229, state: B
# Sent right: 219, state: F
# Sent left: 227, state: B
# Sent right: 219, state: F
# Sent left: 212, state: B
# Sent right: 215, state: F
# Sent left: 211, state: B
# Sent right: 203, state: F
# Sent left: 212, state: B
# Sent right: 166, state: F
# Sent left: 216, state: B
# Sent right: 109, state: F
# Sent left: 215, state: B
# Sent right: 74, state: F
# Sent left: 212, state: B
# Sent right: 44, state: F
# Sent left: 210, state: B
# Sent right: 41, state: F
# Sent left: 213, state: B
# Sent right: 44, state: F
# Sent left: 211, state: B
# Sent right: 40, state: F
# Sent left: 210, state: B
# Sent right: 36, state: F
# Sent left: 211, state: B
# Sent right: 39, state: F
# Sent left: 211, state: B
# Sent right: 39, state: F
# Sent left: 210, state: B
# Sent right: 34, state: F
# Sent left: 209, state: B
# Sent right: 35, state: F
# Sent left: 209, state: B
# Sent right: 37, state: F
# Sent left: 207, state: B
# Sent right: 37, state: F
# Sent left: 205, state: B
# Sent right: 56, state: F
# Sent left: 194, state: B
# Sent right: 139, state: F
# Sent left: 151, state: B
# Sent right: 195, state: F
# Sent left: 101, state: B
# Sent right: 209, state: F
# Sent left: 71, state: B
# Sent right: 212, state: F
# Sent left: 62, state: B
# Sent right: 215, state: F
# Sent left: 56, state: B
# Sent right: 217, state: F
# Sent left: 56, state: B
# Sent right: 223, state: F
# Sent left: 57, state: B
# Sent right: 220, state: F
# Sent left: 56, state: B
# Sent right: 217, state: F
# Sent left: 57, state: B
# Sent right: 215, state: F
# Sent left: 59, state: B
# Sent right: 213, state: F
# Sent left: 60, state: B
# Sent right: 213, state: F
# Sent left: 60, state: B
# Sent right: 211, state: F
# Sent left: 58, state: B
# Sent right: 200, state: F
# Sent left: 114, state: B
# Sent right: 102, state: F
# Sent left: 207, state: B
# Sent right: 51, state: F
# Sent left: 214, state: B
# Sent right: 40, state: F
# Sent left: 223, state: B
# Sent right: 40, state: F
# Sent left: 222, state: B
# Sent right: 39, state: F
# Sent left: 223, state: B
# Sent right: 38, state: F
# Sent left: 218, state: B
# Sent right: 41, state: F
# Sent left: 216, state: B
# Sent right: 42, state: F
# Sent left: 182, state: B
# Sent right: 85, state: F
# Sent left: 101, state: B
# Sent right: 192, state: F
# Sent left: 55, state: B
# Sent right: 209, state: F
# Sent left: 49, state: B
# Sent right: 190, state: F
# Sent left: 51, state: B
# Sent right: 179, state: F
# Sent left: 52, state: B
# Sent right: 176, state: F
# Sent left: 53, state: B
# Sent right: 172, state: F
# Sent left: 52, state: B
# Sent right: 163, state: F
# Sent left: 52, state: B
# Sent right: 163, state: F
# Sent left: 55, state: B
# Sent right: 162, state: F
# Sent left: 57, state: B
# Sent right: 160, state: F
# Sent left: 57, state: B
# Sent right: 161, state: F
# Sent left: 59, state: B
# Sent right: 160, state: F
# Sent left: 71, state: B
# Sent right: 148, state: F
# Sent left: 52, state: B
# Sent right: 63, state: F
# Sent left: 25, state: B
# Sent right: 20, state: F
# Sent left: 21, state: B
# Sent right: 18, state: F
# Sent left: 18, state: B
# Sent right: 18, state: F
# Sent left: 18, state: B
# Sent right: 18, state: F
# Sent left: 20, state: B
# Sent right: 19, state: F
# Sent left: 17, state: B
# Sent right: 21, state: F
# Sent left: 18, state: B
# Sent right: 18, state: F
# Sent left: 17, state: B
# Sent right: 21, state: F
# Sent left: 18, state: B
# Sent right: 20, state: F
# Sent left: 17, state: B
# Sent right: 16, state: F
# Sent left: 18, state: B
# Sent right: 20, state: F
# Sent left: 92, state: B
# Sent right: 97, state: B
# Sent left: 85, state: B
# Sent right: 73, state: B
# Sent left: 104, state: B
# Sent right: 82, state: B
# Sent left: 56, state: B
# Sent right: 0, state: F
# Sent right: 10, state: B
# Sent left: 204, state: B
# Sent right: 191, state: B
# Sent left: 220, state: B
# Sent right: 203, state: B
# Sent left: 216, state: B
# Sent right: 200, state: B
# Sent left: 217, state: B
# Sent right: 201, state: B
# Sent left: 216, state: B
# Sent right: 198, state: B
# Sent left: 217, state: B
# Sent right: 197, state: B
# Sent left: 220, state: B
# Sent right: 197, state: B
# Sent left: 220, state: B
# Sent right: 197, state: B
# Sent left: 221, state: B
# Sent right: 197, state: B
# Sent left: 225, state: B
# Sent right: 202, state: B
# Sent left: 214, state: B
# Sent right: 197, state: B
# Sent left: 135, state: B
# Sent right: 142, state: F
# Sent left: 186, state: B
# Sent right: 133, state: F
# Sent left: 145, state: B
# Sent right: 141, state: F
# Sent left: 161, state: B
# Sent right: 133, state: F
# Sent left: 143, state: B
# Sent right: 121, state: F
# Sent left: 135, state: B
# Sent right: 129, state: F
# Sent left: 137, state: B
# Sent right: 129, state: F
# Sent left: 144, state: B
# Sent right: 118, state: F
# Sent left: 141, state: B
# Sent right: 122, state: F
# Sent left: 134, state: B
# Sent right: 126, state: F
# Sent left: 144, state: B
# Sent right: 122, state: F
# Sent left: 130, state: B
# Sent right: 100, state: F
# Sent left: 198, state: B
# Sent right: 199, state: F
# Sent left: 200, state: B
# Sent right: 202, state: F
# Sent left: 205, state: B
# Sent right: 191, state: F
# Sent left: 202, state: B
# Sent right: 186, state: F
# Sent left: 226, state: B
# Sent right: 187, state: F
# Sent left: 218, state: B
# Sent right: 184, state: F
# Sent left: 222, state: B
# Sent right: 184, state: F
# Sent left: 227, state: B
# Sent right: 185, state: F
# Sent left: 224, state: B
# Sent right: 183, state: F
# Sent left: 226, state: B
# Sent right: 185, state: F
# Sent left: 220, state: B
# Sent right: 182, state: F
# Sent left: 221, state: B
# Sent right: 181, state: F
# Sent left: 212, state: B
# Sent right: 181, state: F
# Sent left: 211, state: B
# Sent right: 179, state: F
# Sent left: 207, state: B
# Sent right: 168, state: F
# Sent left: 200, state: B
# Sent right: 165, state: F
# Sent left: 200, state: B
# Sent right: 167, state: F
# Sent left: 200, state: B
# Sent right: 168, state: F
# Sent left: 197, state: B
# Sent right: 172, state: F
# Sent left: 201, state: B
# Sent right: 172, state: F
# Sent left: 206, state: B
# Sent right: 172, state: F
# Sent left: 202, state: B
# Sent right: 175, state: F
# Sent left: 0, state: F
# Sent left: 13, state: B
# Sent right: 25, state: F
# Sent left: 19, state: B
# Sent right: 19, state: F
# Sent left: 42, state: B

# %% [markdown]
# ## Servo O

# %%
import cv2
import numpy as np
import time
import HandTrackingModule as htm
import math
import serial

ser = serial.Serial('COM5', 9600)

def send_right(right,state):
    ser.write(f"R{right},{state}\n".encode())
    print(f"Sent right: {right}, state: {state}")

def send_left(left, state):
    ser.write(f"L{left}, {state}\n".encode())
    print(f"Sent left: {left}, state: {state}")
    
def send_servo(state):
    ser.write(f"S{state}\n".encode())
    print(f"Sent servo state: {state}")
    
def check_hand_state(fingers):
    # 엄지만 올라가 있고 나머지는 접혀있는 상태
    if fingers[0] == 1 and sum(fingers[1:]) == 0:
        return "Back"
    # 주먹을 쥔 상태 (모든 손가락이 접혀있음)
    elif sum(fingers) == 0:
        return "Fist"
    # 소지만 올라가 있고 나머지는 접혀있는 상태
    elif fingers[0] == 0 and fingers[1] == 0 and fingers[2] == 0 and fingers[3] == 0 and fingers[4] == 1:
        return "Front"
    else:
        return "Other"

def display_hand_state(img, left_state, right_state, left_hand, right_hand):
    # 왼손 상태 표시
    if left_state == "Back":
        cv2.putText(img, "LeftBack", (10, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    else:
        cv2.putText(img, "LeftFront", (10, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    
    # 오른손 상태 표시
    if right_state == "Back":
        cv2.putText(img, "RightBack", (wCam - 150, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    else:
        cv2.putText(img, "RightFront", (wCam - 150, hCam - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # 주먹 상태에 따른 텍스트 표시
    if len(left_hand) != 0 and check_hand_state(detector.fingersUpDown(left_hand, "Left")) == "Fist":
        cv2.putText(img, "Left Fist", (10, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    
    if len(right_hand) != 0 and check_hand_state(detector.fingersUpDown(right_hand, "Right")) == "Fist":
        cv2.putText(img, "Right Fist", (wCam - 150, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

left_state = "Front"
right_state = "Front"

wCam, hCam = 640, 480

cap = cv2.VideoCapture(1)
cap.set(3, wCam)
cap.set(4, hCam)
pTime = 0

detector = htm.handDetector(detectionCon=0.7)

while True:
    success, img = cap.read()
    img = detector.findHands(img)
    left_hand, right_hand = detector.findPosition(img, draw=False)

    # 왼손 처리
    if left_hand:
        # 엄지와 검지 랜드마크 (예: 4번과 8번)
        x1, y1 = left_hand[4][1], left_hand[4][2]
        x2, y2 = left_hand[8][1], left_hand[8][2]
        cx, cy = (x1+x2)//2, (y1+y2)//2
        
        cv2.circle(img, (x1, y1), 5, (255, 0, 0), cv2.FILLED)  # 파란색
        cv2.circle(img, (x2, y2), 5, (255, 0, 0), cv2.FILLED)  # 파란색
        cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 2)  # 파란색 선
        
        cv2.circle(img, (cx,cy), 5, (255,0,255), cv2.FILLED)
        
        left_length = int(math.hypot(x2-x1, y2-y1))
        
        if left_length<=15:
            cv2.circle(img, (cx,cy), 8, (0,255,0), cv2.FILLED)
            send_left(0, "F")
            time.sleep(0.1)
        
        # 주먹여부처리
        fingers_left = detector.fingersUpDown(left_hand, "Left")
        current_left_state = check_hand_state(fingers_left)
        
        # 상태 유지 로직
        if current_left_state == "Back":
            left_state = "Back"
        elif current_left_state == "Front":
            left_state = "Front"
        elif left_state == "Back" and current_left_state != "Front":
            # Back 상태를 유지
            pass
        else:
            left_state = current_left_state
        
        #아두이노 값 전송
        if left_state == "Back":
            send_left(left_length, "B")
            time.sleep(0.1)
        else:
            send_left(left_length, "F")
            time.sleep(0.1)
        

    # 오른손 처리
    if right_hand:
        # 엄지와 검지 랜드마크 (예: 4번과 8번)
        x1, y1 = right_hand[4][1], right_hand[4][2]
        x2, y2 = right_hand[8][1], right_hand[8][2]
        cx, cy = (x1+x2)//2, (y1+y2)//2
        
        cv2.circle(img, (x1, y1), 5, (0, 0, 255), cv2.FILLED)  # 빨간색
        cv2.circle(img, (x2, y2), 5, (0, 0, 255), cv2.FILLED)  # 빨간색
        cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2)  # 빨간색 선
        
        cv2.circle(img, (cx,cy), 5, (255,0,255), cv2.FILLED)
        
        right_length = int(math.hypot(x2-x1, y2-y1))
        
        if right_length<=15:
            cv2.circle(img, (cx,cy), 8, (0,255,0), cv2.FILLED)
            send_right(0, "F")
            time.sleep(0.1)
        
         #주먹여부처리
        fingers_right = detector.fingersUpDown(right_hand, "Right")
        current_right_state = check_hand_state(fingers_right)
        
        # 상태 유지 로직
        if current_right_state == "Back":
            right_state = "Back"
        elif current_right_state == "Front":
            right_state = "Front"
        elif right_state == "Back" and current_right_state != "Front":
            # Back 상태를 유지
            pass
        else:
            right_state = current_right_state
        
        if right_state == "Back":
            send_right(right_length, "B")
            time.sleep(0.1)
        else:
            send_right(right_length, "F")
            time.sleep(0.1)
    
    # 양손이 주먹인지 확인
    if left_state == "Fist" and right_state == "Fist":
        send_servo("ON")
        send_left(0, "F")
        send_right(0, "F")
    else:
        send_servo("OFF")
        
        
    # display_hand_state 함수 호출
    display_hand_state(img, left_state, right_state, left_hand, right_hand)
    
    # fps 확인
    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime
    
    cv2.putText(img, f'FPS: {int(fps)}', (40, 80), cv2.FONT_HERSHEY_COMPLEX,
                1, (255, 0, 0), 3)
    
    cv2.imshow("Img", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):  # 'q' 키를 누르면 종료
        break
        
ser.close()
cap.release()
cv2.destroyAllWindows()
